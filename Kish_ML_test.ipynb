# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
def read_data():
    data = pd.read_csv("E:/Data Science Course/Data_Science/Test 21/Data1.csv")
    return data

# %%
data = read_data()
print(data.head())
# Out:
#    surface  rooms_new  zipcode_new  price_new   latitude  longitude
# 0    138.0        4.0         1060     420000  40.804673 -73.963420
# 1    130.0        5.0         1087     550000  52.355590   5.000561
# 2    116.0        5.0         1061     425000  52.373044   4.837568
# 3     92.0        5.0         1035     349511  52.416895   4.906767
# 4    127.0        4.0         1013    1050000  52.396789   4.876607

# %%
print("the number of rows and columns -",data.shape)
# Out:
# the number of rows and columns - (2182, 6)

# %%
print("The data types -- \n",data.dtypes)
# Out:
# The data types --
#  surface        float64
# rooms_new      float64
# zipcode_new      int64
# price_new       object
# latitude       float64
# longitude      float64
# dtype: object

# %%
df = data.copy()
print(df.head(2))
print(df.shape)
# Out:
#    surface  rooms_new  zipcode_new price_new   latitude  longitude
# 0    138.0        4.0         1060    420000  40.804673 -73.963420
# 1    130.0        5.0         1087    550000  52.355590   5.000561
# (2190, 6)

# %%
print("The missing Records - ")
data.isnull().sum()
# Out:
# The missing Records -
# surface         0
# rooms_new      28
# zipcode_new     0
# price_new       0
# latitude        0
# longitude       0
# dtype: int64

# %%
### Data proofling. Remove Duplicate values 

print("Minimum Rooms -",df["rooms_new"].min())
# Out:
# Minimum Rooms - 0.0

# %%
print("Maximum Rooms -",df["rooms_new"].max())
# Out:
# Maximum Rooms - 9.0

# %%
print("Minimum Price value -",df["price_new"].min())
# Out:
# Minimum Price value - 10000

# %%
print("Maximum Price value -",df["price_new"].max())
# Out:
# Maximum Price value - Prijs op aanvraag

# %%
df = data.copy()
print(df.head(2))
print(df.shape)
# Out:
#    surface  rooms_new  zipcode_new  price_new   latitude  longitude
# 0    138.0        4.0         1060     420000  40.804673 -73.963420
# 1    130.0        5.0         1087     550000  52.355590   5.000561
# (2182, 6)

# %%
### Some Text value in Price_new So removing Manually 
### Manually removed all the rows.
print("Maximum Price value -",df["price_new"].max())
# Out:
# Maximum Price value - 6400000

# %%
### Rooms New column contains some Null values 
df.isnull().values.sum()
# Out:
# 28

# %%
### Percentage of Missing Values

# %%
missing_values = df.isnull().sum()
total_records = len(df)

# %%
### TO know Percentae of MIssing values
percent_missing =  (missing_values/total_records)*100
print("The Percentage of Missing Values - \n", percent_missing)
# Out:
# The Percentage of Missing Values -
#  surface        0.000000
# rooms_new      1.283226
# zipcode_new    0.000000
# price_new      0.000000
# latitude       0.000000
# longitude      0.000000
# dtype: float64

# %%
### Missing values are minimal only 1 Percent we have so No issues it seems.
### Surface column has float values
float_value = df.select_dtypes(include=[float])
float_value
# Out:
#       surface  rooms_new   latitude  longitude
# 0       138.0        4.0  40.804673 -73.963420
# 1       130.0        5.0  52.355590   5.000561
# 2       116.0        5.0  52.373044   4.837568
# 3        92.0        5.0  52.416895   4.906767
# 4       127.0        4.0  52.396789   4.876607
# ...       ...        ...        ...        ...
# 2177     12.0        NaN  52.372858   4.938828
# 2178     12.0        NaN  52.372858   4.938828
# 2179     12.0        NaN  52.372858   4.938828
# 2180     12.0        NaN  52.372858   4.938828
# 2181     64.0        2.0  52.399622   4.936959
#
# [2182 rows x 4 columns]

# %%
### Filling Null values with 0
df.fillna(0)
# Out:
#       surface  rooms_new  zipcode_new  price_new   latitude  longitude
# 0       138.0        4.0         1060     420000  40.804673 -73.963420
# 1       130.0        5.0         1087     550000  52.355590   5.000561
# 2       116.0        5.0         1061     425000  52.373044   4.837568
# 3        92.0        5.0         1035     349511  52.416895   4.906767
# 4       127.0        4.0         1013    1050000  52.396789   4.876607
# ...       ...        ...          ...        ...        ...        ...
# 2177     12.0        0.0         1019      40000  52.372858   4.938828
# 2178     12.0        0.0         1019      40000  52.372858   4.938828
# 2179     12.0        0.0         1019      40000  52.372858   4.938828
# 2180     12.0        0.0         1019      40000  52.372858   4.938828
# 2181     64.0        2.0         1025     211000  52.399622   4.936959
#
# [2182 rows x 6 columns]

# %%
print("The missing Records - ")
df.isnull().values.sum()
# Out:
# The missing Records -
# 28

# %%
plt.figure(figsize =(3,4))
sns.barplot(x = 'surface',y = 'price_new', estimator = 'sum',errorbar =None, data = df)
plt.title ('Suface wise sum of price_new')
# Out:
# Text(0.5, 1.0, 'Suface wise sum of price_new')

# %%
plt.figure(figsize = (5,3))
sns.scatterplot(x ='rooms_new',y='price_new', hue = 'surface', data= df)
plt.title("scatterplot")
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
sns.distplot(x= data['rooms_new'])
print(data['rooms_new'].skew())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3884\4010114633.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= data['rooms_new'])
# 0.9103101089084599

# %%
Heat= data[['surface','rooms_new','price_new','latitude','longitude']].corr()
Heat
# Out:
#             surface  rooms_new  price_new  latitude  longitude
# surface    1.000000   0.602219   0.854262 -0.072466  -0.071946
# rooms_new  0.602219   1.000000   0.449476 -0.090688  -0.090030
# price_new  0.854262   0.449476   1.000000  0.035820   0.035855
# latitude  -0.072466  -0.090688   0.035820  1.000000   0.999904
# longitude -0.071946  -0.090030   0.035855  0.999904   1.000000

# %%
sns.heatmap(Heat, annot = True, cmap = 'rocket')
# Out:
# <Axes: >

# %%
sns.pairplot(data[['surface','rooms_new','price_new','latitude','longitude']])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(y=data['rooms_new'])
# Out:
# <Axes: ylabel='rooms_new'>

# %%
sns.swarmplot(y=data['surface'])
# Out:
# <Axes: ylabel='surface'>
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x= df[['surface','price_new','latitude','longitude']]
y = df['rooms_new']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.15,random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((1854, 4), (328, 4))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df.fillna(0)
# Out:
#       surface  rooms_new  zipcode_new  price_new   latitude  longitude
# 0       138.0        4.0         1060     420000  40.804673 -73.963420
# 1       130.0        5.0         1087     550000  52.355590   5.000561
# 2       116.0        5.0         1061     425000  52.373044   4.837568
# 3        92.0        5.0         1035     349511  52.416895   4.906767
# 4       127.0        4.0         1013    1050000  52.396789   4.876607
# ...       ...        ...          ...        ...        ...        ...
# 2177     12.0        0.0         1019      40000  52.372858   4.938828
# 2178     12.0        0.0         1019      40000  52.372858   4.938828
# 2179     12.0        0.0         1019      40000  52.372858   4.938828
# 2180     12.0        0.0         1019      40000  52.372858   4.938828
# 2181     64.0        2.0         1025     211000  52.399622   4.936959
#
# [2182 rows x 6 columns]

# %%
model_train = model.fit(x_train, y_train)

# %%
print("The missing Records - ")
df.isnull().sum()
# Out:
# The missing Records -
# surface         0
# rooms_new      28
# zipcode_new     0
# price_new       0
# latitude        0
# longitude       0
# dtype: int64

# %%
df=df.fillna(0)

# %%
print("Filled the Null values with 0 - ")
df.isnull().sum()
# Out:
# The missing Records -
# surface        0
# rooms_new      0
# zipcode_new    0
# price_new      0
# latitude       0
# longitude      0
# dtype: int64

# %%
model_train = model.fit(x_train, y_train)

# %%
pred= model.predict(x_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
mean_squared_erro = mean_squared_error(y_test,pred)
print("Mean Squared Error is - ", mean_squared_erro)
# Out:
# Mean Squared Error is -  1.5049672539007042

# %%
from math import sqrt

# %%
root_mean_squared_err = sqrt(mean_squared_erro)
print("Root Mean Squared Error is - ", root_mean_squared_err)
# Out:
# Root Mean Squared Error is -  1.2267710682522246

# %%
print("Model Co-efficient values - ", model.coef_)
# Out:
# Model Co-efficient values -  [ 1.71178963e-02 -4.73792954e-07 -1.13291721e+00  1.61511347e-01]

# %%
print("Model Intercept Value is - ", model.intercept_)
# Out:
# Model Intercept Value is -  60.581561752289296

# %%
df1 = data.copy()
print(df.head(2))
print(df.shape)
# Out:
#    surface  rooms_new  zipcode_new  price_new   latitude  longitude
# 0    138.0        4.0         1060     420000  40.804673 -73.963420
# 1    130.0        5.0         1087     550000  52.355590   5.000561
# (2182, 6)

# %%
x= df[['surface','price_new','latitude','longitude']]
y = df['rooms_new']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20)

# %%
### Model Building
from sklearn.neighbors import KNeighborsRegressor

# %%
KKmodel = KNeighborsRegressor(n_neighbors =5)

# %%
KKModel_train = model.fit(x_train, y_train)
print("The Model Training is completed")
# Out:
# The Model Training is completed

# %%
from sklearn.metrics import r2_score, mean_squared_error
pred =  model_train.predict(x_test)

# %%
r2_score(y_test,pred)
# Out:
# 0.37379491043652724

# %%
### choose the value of k - Based on error
error =[]
k= []
for i in range(1,10):
    print("when K =", i)
    KKmodel =  KNeighborsRegressor(n_neighbors =5)
    KKModel_train = model.fit(x_train, y_train)
    print("The Model training is completed")
    err = 1-model_train.score(x_train, y_train)
    error.append(err)
    k.append()
# Out:
# when K = 1
# The Model training is completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 11
#       9 err = 1-model_train.score(x_train, y_train)
#      10 error.append(err)
# ---> 11 k.append()
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
### choose the value of k - Based on error
error = []
k = []
for i in range(1,10):
    print("when K =", i)
    KKmodel =  KNeighborsRegressor(n_neighbors =i)
    KKModel_train = model.fit(x_train, y_train)
    print("The Model training is completed")
    err = 1-model_train.score(x_train, y_train)
    error.append(err)
    k.append(i)
# Out:
# when K = 1
# The Model training is completed
# when K = 2
# The Model training is completed
# when K = 3
# The Model training is completed
# when K = 4
# The Model training is completed
# when K = 5
# The Model training is completed
# when K = 6
# The Model training is completed
# when K = 7
# The Model training is completed
# when K = 8
# The Model training is completed
# when K = 9
# The Model training is completed

# %%
error
# Out:
# [0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453,
#  0.6330535480934453]

# %%
k
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import joblib
import pandas as pd

# %%
### KNN_ML Test.sav file is saved.
joblib.dump(KKmodel, 'KNN_MLTest.sav')
# Out:
# ['KNN_MLTest.sav']

# %%
### loading the model
filename = 'KNN_MLTest.sav'
sav_model = joblib.load(filename)
print(sav_model)
# Out:
# KNeighborsRegressor(n_neighbors=9)

# %%
### I will take Latitude and Longitude
latitude = [52.3817073,52.3663937,52.3797728]
longitude = [4.9388278,4.8907747,4.8540225]
raw_data = pd.DataFrame({'Latitude' :latitude,'Longitude':longitude})
raw_data
# Out:
#     Latitude  Longitude
# 0  52.381707   4.938828
# 1  52.366394   4.890775
# 2  52.379773   4.854023
